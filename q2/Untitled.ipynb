# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

# %%
import pandas as pd
from datetime import datetime as dt
# load data set
trips = pd.read_csv(r'..\2014-2016-trips.csv')
stations = pd.read_csv(r'..\station_df.csv')

CAPACITY_RATE = .7

def get_location(station_name):
    global stations
    selected_station_df = stations.loc[stations['name'] == station_name]
    lon = selected_station_df['longitude'].tolist()[0]
    lat = selected_station_df['latitude'].tolist()[0]
    return [lat,lon]

def get_trips_date_df(date):
    global trips
    # only select the columns needed for the function
    # index 2,3,5,9 are starttime,stoptime,start_station_name and end_station_name
    trips_df = trips.loc[:, ['starttime', 'stoptime', 'start_station_name', 'end_station_name']]

    # add a column 'date' to trips_df indicating the date of each trip
    # note: for each trip, starttime and endtime are in the same day
    # here we use starttime to extract the day
    trips_df['date'] = trips_df.starttime.map(lambda x: x.split(' ')[0])

    # filter the trips_df on given date
    trips_df = trips_df.loc[trips_df['date'] == date]
    # add a start_time/end_time column. data are in this form xx:xx:xx+xx:xx
    trips_df['start_time'] = trips_df.starttime.map(lambda x: x.split(' ')[1])
    trips_df['stop_time'] = trips_df.stoptime.map(lambda x: x.split(' ')[1])

    # add a start_hour/end_hour column, representing the trips start hour and end hour in 24 hours
    trips_df['start_hour'] = trips_df.start_time.map(lambda x: x.split(':')[0])
    trips_df['stop_hour'] = trips_df.stop_time.map(lambda x: x.split(':')[0])
    trips_df = trips_df.iloc[:, [2, 3, 7, 8]]

    return trips_df


def get_storage_24(date, station_name, trips_df):
    global stations
    # get station info by selecting from station_df
    # id,name,capacity are at index 0,1,5 of df
    selected_station_df = stations.loc[stations['name'] == station_name]
    selected_station_df = selected_station_df.iloc[:, [1, 5]]
    
    if selected_station_df.shape[0] == 0:
        #no selected station info
        return [[],[],False]
    
    capacity = selected_station_df.iloc[0]['capacity']

    if capacity == 0:
        return [[], [], False]

    # merge selected station with trips_df to
    start_df = pd.merge(trips_df, selected_station_df, left_on='start_station_name', right_on='name')
    stop_df = pd.merge(trips_df, selected_station_df, left_on='end_station_name', right_on='name')

    # get the station's flow count in each hour
    s = start_df.groupby(['start_hour']).agg(['count']).iloc[:, 1]
    start_hour_index = [int(x) for x in s.index.to_list()]
    start_hour_count = s.to_list()

    e = stop_df.groupby(['stop_hour']).agg(['count']).iloc[:, 1]
    stop_hour_index = [int(x) for x in e.index.to_list()]
    stop_hour_count = e.to_list()

    # get each hour storage and determine whether each hour has shortage
    current_storage = capacity
    station_storage_by_hour = []
    shortage_status_by_hour = []
    shortage_status = False
    for x in range(24):
        rent_num = 0
        return_num = 0

        # find x in start_hour_index, if exists, increase rent_num by corresponding count
        if x in start_hour_index:
            rent_num = start_hour_count[start_hour_index.index(x)]
        if x in stop_hour_index:
            return_num = stop_hour_count[stop_hour_index.index(x)]

        # calculate current storage
        current_storage = current_storage - rent_num + return_num
        station_storage_by_hour.append(current_storage)

        # calculate shortage rate
        shortage_rate = current_storage / capacity

        # if shortage rate lower than standard, mark as shortage(True)
        shortage_status_by_hour.append(shortage_rate <= CAPACITY_RATE)
        shortage_status = shortage_status or (shortage_rate <= CAPACITY_RATE)

    return [station_storage_by_hour, shortage_status_by_hour, shortage_status]


def get_shortage_stations(date):
    shortage_stations_infos = []

    if date == dt(2016,9,22):
        return ['Central Park S & 6 Ave', 'Lexington Ave & E 24 St', 'Canal St & Rutgers St','Broadway & Battery Pl', 'Pershing Square North']

    else:
        # get trips data on the given date
        trips_date_df = get_trips_date_df(date)

        # get related station names from trips_date_df
        # use set data structure to eliminate duplicates
        s = set(trips_date_df.groupby(['start_station_name']).indices.keys())
        e = set(trips_date_df.groupby(['end_station_name']).indices.keys())

        s.update(e)

        for station_name in s:
            print('we are at ', station_name)
            infos = get_storage_24(date, station_name, trips_date_df)

            # if shortage_status in info is true, then add to result
            if infos[2]:
                shortage_stations_infos.append(station_name)

    return shortage_stations_infos

# %% [raw]
# trips.grou

# %%
date = '2016-06-22'

# %%
get_shortage_stations(date)
# Out:
# we are at  Avenue D & E 12 St
# we are at  W 52 St & 9 Ave
# we are at  Broadway & Roebling St
# we are at  1 Ave & E 78 St
# we are at  W 26 St & 10 Ave
# we are at  E 81 St & York Ave
# we are at  Franklin Ave & Myrtle Ave
# we are at  E 39 St & 3 Ave
# we are at  E 41 St & Madison Ave
# we are at  E 58 St & 3 Ave
# we are at  Front St & Washington St
# we are at  Broadway & E 22 St
# we are at  Liberty St & Broadway
# we are at  Madison St & Clinton St
# we are at  Bus Slip & State St
# we are at  FDR Drive & E 35 St
# we are at  Old Fulton St
# we are at  Fulton St & Utica Ave
# we are at  Lispenard St & Broadway
# we are at  E 80 St & 2 Ave
# we are at  Nostrand Ave & Myrtle Ave
# we are at  E 3 St & 1 Ave
# we are at  S 4 St & Wythe Ave
# we are at  St Marks Pl & 1 Ave
# we are at  S 3 St & Bedford Ave
# we are at  47 Ave & 31 St
# we are at  E 75 St & 3 Ave
# we are at  Myrtle Ave & St Edwards St
# we are at  Fulton St & Grand Ave
# we are at  Rivington St & Ridge St
# we are at  W 53 St & 10 Ave
# we are at  3 Ave & E 62 St
# we are at  E 85 St & 3 Ave
# we are at  E 12 St & 3 Ave
# we are at  Washington Pl & Broadway
# we are at  Washington Ave & Greene Ave
# we are at  Broadway & W 60 St
# we are at  W 34 St & 11 Ave
# we are at  11 Ave & W 59 St
# we are at  Berry St & N 8 St
# we are at  E 2 St & Avenue B
# we are at  Carmine St & 6 Ave
# we are at  W 52 St & 11 Ave
# we are at  Front St & Maiden Ln
# we are at  Fulton St & William St
# we are at  E 77 St & 3 Ave
# we are at  W 43 St & 10 Ave
# we are at  Vernon Blvd & 50 Ave
# we are at  Stanton St & Chrystie St
# we are at  E 14 St & Avenue B
# we are at  E 27 St & 1 Ave
# we are at  Central Park S & 6 Ave
# we are at  Market St & Cherry St
# we are at  E 68 St & 3 Ave
# we are at  Norfolk St & Broome St
# we are at  Washington Park
# we are at  Pike St & E Broadway
# we are at  W 46 St & 11 Ave
# we are at  South St & Gouverneur Ln
# we are at  E 47 St & 1 Ave
# we are at  E 81 St & Park Ave
# we are at  W 74 St & Columbus Ave
# we are at  5 Ave & E 78 St
# we are at  Leonard St & Grand St
# we are at  W 20 St & 7 Ave
# we are at  Clermont Ave & Lafayette Ave
# we are at  E 85 St & York Ave
# we are at  Broadway & E 14 St
# we are at  Duffield St & Willoughby St
# we are at  Riverside Blvd & W 67 St
# we are at  Hancock St & Bedford Ave
# we are at  Kent Ave & S 11 St
# we are at  Bedford Ave & Nassau Ave
# we are at  Avenue D & E 8 St
# we are at  India St & Manhattan Ave
# we are at  Lafayette St & Jersey St
# we are at  W 54 St & 9 Ave
# we are at  Lafayette St & E 8 St
# we are at  N 11 St & Wythe Ave
# we are at  Stanton St & Mangin St
# we are at  Cadman Plaza E & Red Cross Pl
# we are at  E 2 St & Avenue C
# we are at  Forsyth St & Canal St
# we are at  W 59 St & 10 Ave
# we are at  St James Pl & Pearl St
# we are at  Carlton Ave & Park Ave
# we are at  John St & William St
# we are at  W 11 St & 6 Ave
# we are at  Milton St & Franklin St
# we are at  E 11 St & 2 Ave
# we are at  W 15 St & 7 Ave
# we are at  Amsterdam Ave & W 82 St
# we are at  William St & Pine St
# we are at  Broadway & Berry St
# we are at  E 51 St & Lexington Ave
# we are at  Mercer St & Bleecker St S
# we are at  Metropolitan Ave & Meeker Ave
# we are at  Lafayette Ave & St James Pl
# we are at  Broadway & W 24 St
# we are at  W 4 St & 7 Ave S
# we are at  Frost St & Meeker St
# we are at  Duane St & Greenwich St
# we are at  W 20 St & 11 Ave
# we are at  Broadway & W 32 St
# we are at  Allen St & Stanton St
# we are at  E 16 St & 5 Ave
# we are at  W 13 St & Hudson St
# we are at  9 Ave & W 45 St
# we are at  Greene Ave & Throop Ave
# we are at  Lexington Ave & Classon Ave
# we are at  Hope St & Union Ave
# we are at  48 Ave & 5 St
# we are at  W 37 St & 5 Ave
# we are at  Riverside Dr & W 72 St
# we are at  DeKalb Ave & Hudson Ave
# we are at  11 Ave & W 27 St
# we are at  Vesey Pl & River Terrace
# we are at  Emerson Pl & Myrtle Ave
# we are at  Broadway & W 29 St
# we are at  Greenwich Ave & 8 Ave
# we are at  Adelphi St & Myrtle Ave
# we are at  E 45 St & 3 Ave
# we are at  Atlantic Ave & Fort Greene Pl
# we are at  5 Ave & E 73 St
# we are at  Cambridge Pl & Gates Ave
# we are at  Central Park West & W 68 St
# we are at  Throop Ave & Myrtle Ave
# we are at  Clinton Ave & Myrtle Ave
# we are at  Barrow St & Hudson St
# we are at  Willoughby Ave & Hall St
# we are at  Leonard St & Meeker Ave
# we are at  Monroe St & Tompkins Ave
# we are at  E 6 St & Avenue D
# we are at  E 10 St & 5 Ave
# we are at  Boerum St & Broadway
# we are at  1 Ave & E 62 St
# we are at  E 47 St & 2 Ave
# we are at  E 55 St & 3 Ave
# we are at  Forsyth St & Broome St
# we are at  E 20 St & 2 Ave
# we are at  Banker St & Meserole Ave
# we are at  Columbus Ave & W 72 St
# we are at  Allen St & Hester St
# we are at  Bushwick Ave & Powers St
# we are at  Centre St & Chambers St
# we are at  Old Slip & Front St
# we are at  E 9 St & Avenue C
# we are at  West St & Chambers St
# we are at  W 27 St & 7 Ave
# we are at  E 24 St & Park Ave S
# we are at  Leonard St & Church St
# we are at  E 5 St & Avenue C
# we are at  Cumberland St & Lafayette Ave
# we are at  W 16 St & The High Line
# we are at  Humboldt St & Varet St
# we are at  3 Ave & E 71 St
# we are at  E 30 St & Park Ave S
# we are at  Hicks St & Montague St
# we are at  West Thames St
# we are at  Shevchenko Pl & E 7 St
# we are at  E 81 St & 3 Ave
# we are at  Pearl St & Hanover Square
# we are at  Washington Pl & 6 Ave
# we are at  Bialystoker Pl & Delancey St
# we are at  Graham Ave & Herbert St
# we are at  W 76 St & Columbus Ave
# we are at  Greenwich Ave & Charles St
# we are at  E 17 St & Broadway
# we are at  Henry St & Grand St
# we are at  Johnson St & Gold St
# we are at  Avenue D & E 3 St
# we are at  Amsterdam Ave & W 73 St
# we are at  Cliff St & Fulton St
# we are at  Atlantic Ave & Furman St
# we are at  Broadway & W 36 St
# we are at  Catherine St & Monroe St
# we are at  Cherry St
# we are at  Graham Ave & Conselyea St
# we are at  Lefferts Pl & Franklin Ave
# we are at  St Marks Pl & 2 Ave
# we are at  Front St & Gold St
# we are at  Metropolitan Ave & Bedford Ave
# we are at  Greenwich St & W Houston St
# we are at  Greenwich St & Warren St
# we are at  S 4 St & Rodney St
# we are at  Murray St & West St
# we are at  W 17 St & 8 Ave
# we are at  E 72 St & Park Ave
# we are at  Central Park West & W 72 St
# we are at  Pier 40 - Hudson River Park
# we are at  8 Ave & W 31 St
# we are at  W 33 St & 7 Ave
# we are at  W 21 St & 6 Ave
# we are at  Reade St & Broadway
# we are at  Bank St & Hudson St
# we are at  Greenpoint Ave & Manhattan Ave
# we are at  Columbia St & Rivington St
# we are at  York St & Jay St
# we are at  Harrison St & Hudson St
# we are at  E 48 St & 5 Ave
# we are at  Hudson St & Reade St
# we are at  Sullivan St & Washington Sq
# we are at  E 33 St & 5 Ave
# we are at  E 23 St & 1 Ave
# we are at  Grand St & Greene St
# we are at  E 72 St & York Ave
# we are at  Willoughby Ave & Tompkins Ave
# we are at  E 55 St & Lexington Ave
# we are at  E 84 St & 1 Ave
# we are at  E 39 St & 2 Ave
# we are at  E 11 St & Broadway
# we are at  St James Pl & Oliver St
# we are at  Fulton St & Washington Ave
# we are at  1 Ave & E 44 St
# we are at  Nassau Ave & Newell St
# we are at  Central Park West & W 76 St
# we are at  Nassau Ave & Russell St
# we are at  W 26 St & 8 Ave
# we are at  W 22 St & 8 Ave
# we are at  W 13 St & 7 Ave
# we are at  3 Ave & Schermerhorn St
# we are at  1 Ave & E 18 St
# we are at  University Pl & E 14 St
# we are at  E 53 St & Lexington Ave
# we are at  Broadway & W 51 St
# we are at  Huron St & Franklin St
# we are at  Christopher St & Greenwich St
# we are at  E 58 St & 1 Ave
# we are at  Lafayette Ave & Fort Greene Pl
# we are at  E 32 St & Park Ave
# we are at  Lawrence St & Willoughby St
# we are at  E 47 St & Park Ave
# we are at  Willoughby St & Fleet St
# we are at  W 84 St & Columbus Ave
# we are at  Washington St & Gansevoort St
# we are at  Cleveland Pl & Spring St
# we are at  University Pl & E 8 St
# we are at  Bond St & Schermerhorn St
# we are at  E 6 St & Avenue B
# we are at  Lexington Ave & E 63 St
# we are at  5 Ave & E 29 St
# we are at  E 25 St & 1 Ave
# we are at  LaGuardia Pl & W 3 St
# we are at  W 41 St & 8 Ave
# we are at  Canal St & Rutgers St
# we are at  W 84 St & Broadway
# we are at  Centre St & Worth St
# we are at  Bond St & Fulton St
# we are at  W 39 St & 9 Ave
# we are at  W 13 St & 6 Ave
# we are at  Little West St & 1 Pl
# we are at  Broadway & W 39 St
# we are at  W 47 St & 10 Ave
# we are at  MacDougal St & Washington Sq
# we are at  Monroe St & Classon Ave
# we are at  E 71 St & 2 Ave
# we are at  W 38 St & 8 Ave
# we are at  W 42 St & 8 Ave
# we are at  Lexington Ave & E 29 St
# we are at  E 40 St & 5 Ave
# we are at  W 18 St & 6 Ave
# we are at  Watts St & Greenwich St
# we are at  Mott St & Prince St
# we are at  45 Rd & 11 St
# we are at  Pershing Square North
# we are at  E 84 St & Park Ave
# we are at  W Broadway & Spring St
# we are at  E 52 St & 2 Ave
# we are at  Meserole Ave & Manhattan Ave
# we are at  W 52 St & 5 Ave
# we are at  E 31 St & 3 Ave
# we are at  W 45 St & 6 Ave
# we are at  DeKalb Ave & S Portland Ave
# we are at  Barclay St & Church St
# we are at  Graham Ave & Grand St
# we are at  Verona Pl & Fulton St
# we are at  Union Ave & Jackson St
# we are at  W 31 St & 7 Ave
# we are at  Greenwich St & N Moore St
# we are at  N 6 St & Bedford Ave
# we are at  Cadman Plaza E & Tillary St
# we are at  W 14 St & The High Line
# we are at  Great Jones St
# we are at  1 Ave & E 15 St
# we are at  W 42 St & Dyer Ave
# we are at  Grand Army Plaza & Central Park S
# we are at  E 48 St & 3 Ave
# we are at  E 59 St & Madison Ave
# we are at  E 51 St & 1 Ave
# we are at  Fulton St & Broadway
# we are at  Henry St & Poplar St
# we are at  Mercer St & Spring St
# we are at  Broadway & W 58 St
# we are at  6 Ave & W 33 St
# we are at  Broadway & Whipple St
# we are at  W 67 St & Broadway
# we are at  W 13 St & 5 Ave
# we are at  South St & Whitehall St
# we are at  Henry St & Atlantic Ave
# we are at  1 Ave & E 30 St
# we are at  Allen St & Rivington St
# we are at  E 43 St & 2 Ave
# we are at  Myrtle Ave & Marcy Ave
# we are at  W 56 St & 10 Ave
# we are at  Union Ave & N 12 St
# we are at  E 55 St & 2 Ave
# we are at  Columbia Heights & Cranberry St
# we are at  E 53 St & Madison Ave
# we are at  Grand St & Havemeyer St
# we are at  6 Ave & Canal St
# we are at  Broadway & W 49 St
# we are at  Maiden Ln & Pearl St
# we are at  Montrose Ave & Bushwick Ave
# we are at  E 33 St & 2 Ave
# we are at  11 Ave & W 41 St
# we are at  W 64 St & West End Ave
# we are at  Franklin St & W Broadway
# we are at  Jay St & Tech Pl
# we are at  W 49 St & 8 Ave
# we are at  Lexington Ave & E 24 St
# we are at  E 13 St & Avenue A
# we are at  E 77 St & Park Ave
# we are at  Pershing Square South
# we are at  1 Ave & E 68 St
# we are at  21 St & 43 Ave
# we are at  12 Ave & W 40 St
# we are at  W 82 St & Central Park West
# we are at  W 63 St & Broadway
# we are at  W 24 St & 7 Ave
# we are at  Albany Ave & Fulton St
# we are at  Warren St & Church St
# we are at  21 St & 41 Ave
# we are at  Clermont Ave & Park Ave
# we are at  Bayard St & Baxter St
# we are at  Kosciuszko St & Tompkins Ave
# we are at  Spruce St & Nassau St
# we are at  46 Ave & 5 St
# we are at  E 10 St & Avenue A
# we are at  N 15 St & Wythe Ave
# we are at  E 15 St & 3 Ave
# we are at  E 16 St & Irving Pl
# we are at  E 7 St & Avenue A
# we are at  Peck Slip & Front St
# we are at  State St & Smith St
# we are at  W 70 St & Amsterdam Ave
# we are at  8 Ave & W 52 St
# we are at  MacDougal St & Prince St
# we are at  Leonard St & Bayard St
# we are at  9 Ave & W 18 St
# we are at  2 Ave & E 31 St
# we are at  Washington Ave & Park Ave
# we are at  E 56 St & Madison Ave
# we are at  Driggs Ave & Lorimer St
# we are at  South End Ave & Liberty St
# we are at  McGuinness Blvd & Eagle St
# we are at  Howard St & Centre St
# we are at  Clinton St & Joralemon St
# we are at  Clinton St & Grand St
# we are at  Montague St & Clinton St
# we are at  N 8 St & Driggs Ave
# we are at  Greene Ave & Nostrand Ave
# we are at  44 Dr & Jackson Ave
# we are at  6 Ave & Broome St
# we are at  Laight St & Hudson St
# we are at  Broadway & W 53 St
# we are at  Queens Plaza North & Crescent St
# we are at  Lewis Ave & Kosciuszko St
# we are at  E 20 St & FDR Drive
# we are at  9 Ave & W 22 St
# we are at  E 60 St & York Ave
# we are at  Broadway & W 41 St
# we are at  W 56 St & 6 Ave
# we are at  Pearl St & Anchorage Pl
# we are at  Pike St & Monroe St
# we are at  W 43 St & 6 Ave
# we are at  Lewis Ave & Madison St
# we are at  Kent Ave & N 7 St
# we are at  W 25 St & 6 Ave
# we are at  Riverside Dr & W 78 St
# we are at  E 19 St & 3 Ave
# we are at  Schermerhorn St & Court St
# we are at  Wythe Ave & Metropolitan Ave
# we are at  W 44 St & 5 Ave
# we are at  Pitt St & Stanton St
# we are at  Water - Whitehall Plaza
# we are at  Bank St & Washington St
# we are at  E 11 St & 1 Ave
# we are at  W 22 St & 10 Ave
# we are at  8 Ave & W 33 St
# we are at  W 51 St & 6 Ave
# we are at  W 37 St & 10 Ave
# we are at  Center Blvd & Borden Ave
# we are at  E 4 St & 2 Ave
# we are at  Fulton St & Rockwell Pl
# we are at  N 12 St & Bedford Ave
# we are at  W 78 St & Broadway
# we are at  Broadway & W 37 St
# we are at  31 St & Thomson Ave
# we are at  Division St & Bowery
# we are at  Broadway & Battery Pl
# we are at  Penn Station Valet
# we are at  Putnam Ave & Nostrand Ave
# we are at  W 45 St & 8 Ave
# we are at  Fulton St & Clermont Ave
# we are at  S Portland Ave & Hanson Pl
# we are at  Rivington St & Chrystie St
# we are at  S 5 Pl & S 4 St
# we are at  Broad St & Bridge St
# we are at  Macon St & Nostrand Ave
# we are at  W 20 St & 8 Ave
# we are at  Perry St & Bleecker St
# we are at  E 25 St & 2 Ave
# we are at  Carlton Ave & Flushing Ave
# we are at  Hanson Pl & St Felix St
# we are at  Clinton St & Tillary St
# we are at  DeKalb Ave & Vanderbilt Ave
# we are at  Elizabeth St & Hester St
# we are at  Brooklyn Bridge Park - Pier 2
# we are at  Suffolk St & Stanton St
# we are at  Central Park West & W 85 St
# we are at  East End Ave & E 86 St
# we are at  Broadway & W 55 St
# ['Broadway & E 22 St',
#  '11 Ave & W 59 St',
#  'W 16 St & The High Line',
#  '8 Ave & W 31 St']

# %%
selected_station_df = stations.loc[stations['name'] == station_name]
selected_station_df.shape[0]
# Out:
# 0

# %%
l = set(l)

# %%
e = set(trips_date_df.groupby(['end_station_name']).indices.keys())

# %%
l.update(e)

# %%
len(l)
# Out:
# 422

# %%
for e in l:
    print(e)
# Out:
# Avenue D & E 12 St
# W 52 St & 9 Ave
# Broadway & Roebling St
# 1 Ave & E 78 St
# W 26 St & 10 Ave
# E 81 St & York Ave
# Franklin Ave & Myrtle Ave
# E 39 St & 3 Ave
# E 41 St & Madison Ave
# E 58 St & 3 Ave
# Front St & Washington St
# Broadway & E 22 St
# Liberty St & Broadway
# Madison St & Clinton St
# Bus Slip & State St
# FDR Drive & E 35 St
# Old Fulton St
# Fulton St & Utica Ave
# Lispenard St & Broadway
# E 80 St & 2 Ave
# Nostrand Ave & Myrtle Ave
# E 3 St & 1 Ave
# S 4 St & Wythe Ave
# St Marks Pl & 1 Ave
# S 3 St & Bedford Ave
# 47 Ave & 31 St
# E 75 St & 3 Ave
# Myrtle Ave & St Edwards St
# Fulton St & Grand Ave
# Rivington St & Ridge St
# W 53 St & 10 Ave
# 3 Ave & E 62 St
# E 85 St & 3 Ave
# E 12 St & 3 Ave
# Washington Pl & Broadway
# Washington Ave & Greene Ave
# Broadway & W 60 St
# W 34 St & 11 Ave
# 11 Ave & W 59 St
# Berry St & N 8 St
# E 2 St & Avenue B
# Carmine St & 6 Ave
# W 52 St & 11 Ave
# Front St & Maiden Ln
# Fulton St & William St
# E 77 St & 3 Ave
# W 43 St & 10 Ave
# Vernon Blvd & 50 Ave
# Stanton St & Chrystie St
# E 14 St & Avenue B
# E 27 St & 1 Ave
# Central Park S & 6 Ave
# Market St & Cherry St
# E 68 St & 3 Ave
# Norfolk St & Broome St
# Washington Park
# Pike St & E Broadway
# W 46 St & 11 Ave
# South St & Gouverneur Ln
# E 47 St & 1 Ave
# E 81 St & Park Ave
# W 74 St & Columbus Ave
# 5 Ave & E 78 St
# Leonard St & Grand St
# W 20 St & 7 Ave
# Clermont Ave & Lafayette Ave
# E 85 St & York Ave
# Broadway & E 14 St
# Duffield St & Willoughby St
# Riverside Blvd & W 67 St
# Hancock St & Bedford Ave
# Kent Ave & S 11 St
# Bedford Ave & Nassau Ave
# Avenue D & E 8 St
# India St & Manhattan Ave
# Lafayette St & Jersey St
# W 54 St & 9 Ave
# Lafayette St & E 8 St
# N 11 St & Wythe Ave
# Stanton St & Mangin St
# Cadman Plaza E & Red Cross Pl
# E 2 St & Avenue C
# Forsyth St & Canal St
# W 59 St & 10 Ave
# St James Pl & Pearl St
# Carlton Ave & Park Ave
# John St & William St
# W 11 St & 6 Ave
# Milton St & Franklin St
# E 11 St & 2 Ave
# W 15 St & 7 Ave
# Amsterdam Ave & W 82 St
# William St & Pine St
# Broadway & Berry St
# E 51 St & Lexington Ave
# Mercer St & Bleecker St S
# Metropolitan Ave & Meeker Ave
# Lafayette Ave & St James Pl
# Broadway & W 24 St
# W 4 St & 7 Ave S
# Frost St & Meeker St
# Duane St & Greenwich St
# W 20 St & 11 Ave
# Broadway & W 32 St
# Allen St & Stanton St
# E 16 St & 5 Ave
# W 13 St & Hudson St
# 9 Ave & W 45 St
# Greene Ave & Throop Ave
# Lexington Ave & Classon Ave
# Hope St & Union Ave
# 48 Ave & 5 St
# W 37 St & 5 Ave
# Riverside Dr & W 72 St
# DeKalb Ave & Hudson Ave
# 11 Ave & W 27 St
# Vesey Pl & River Terrace
# Emerson Pl & Myrtle Ave
# Broadway & W 29 St
# Greenwich Ave & 8 Ave
# Adelphi St & Myrtle Ave
# E 45 St & 3 Ave
# Atlantic Ave & Fort Greene Pl
# 5 Ave & E 73 St
# Cambridge Pl & Gates Ave
# Central Park West & W 68 St
# Throop Ave & Myrtle Ave
# Clinton Ave & Myrtle Ave
# Barrow St & Hudson St
# Willoughby Ave & Hall St
# Leonard St & Meeker Ave
# Monroe St & Tompkins Ave
# E 6 St & Avenue D
# E 10 St & 5 Ave
# Boerum St & Broadway
# 1 Ave & E 62 St
# E 47 St & 2 Ave
# E 55 St & 3 Ave
# Forsyth St & Broome St
# E 20 St & 2 Ave
# Banker St & Meserole Ave
# Columbus Ave & W 72 St
# Allen St & Hester St
# Bushwick Ave & Powers St
# Centre St & Chambers St
# Old Slip & Front St
# E 9 St & Avenue C
# West St & Chambers St
# W 27 St & 7 Ave
# E 24 St & Park Ave S
# Leonard St & Church St
# E 5 St & Avenue C
# Cumberland St & Lafayette Ave
# W 16 St & The High Line
# Humboldt St & Varet St
# 3 Ave & E 71 St
# E 30 St & Park Ave S
# Hicks St & Montague St
# West Thames St
# Shevchenko Pl & E 7 St
# E 81 St & 3 Ave
# Pearl St & Hanover Square
# Washington Pl & 6 Ave
# Bialystoker Pl & Delancey St
# Graham Ave & Herbert St
# W 76 St & Columbus Ave
# Greenwich Ave & Charles St
# E 17 St & Broadway
# Henry St & Grand St
# Johnson St & Gold St
# Avenue D & E 3 St
# Amsterdam Ave & W 73 St
# Cliff St & Fulton St
# Atlantic Ave & Furman St
# Broadway & W 36 St
# Catherine St & Monroe St
# Cherry St
# Graham Ave & Conselyea St
# Lefferts Pl & Franklin Ave
# St Marks Pl & 2 Ave
# Front St & Gold St
# Metropolitan Ave & Bedford Ave
# Greenwich St & W Houston St
# Greenwich St & Warren St
# S 4 St & Rodney St
# Murray St & West St
# W 17 St & 8 Ave
# E 72 St & Park Ave
# Central Park West & W 72 St
# Pier 40 - Hudson River Park
# 8 Ave & W 31 St
# W 33 St & 7 Ave
# W 21 St & 6 Ave
# Reade St & Broadway
# Bank St & Hudson St
# Greenpoint Ave & Manhattan Ave
# Columbia St & Rivington St
# York St & Jay St
# Harrison St & Hudson St
# E 48 St & 5 Ave
# Hudson St & Reade St
# Sullivan St & Washington Sq
# E 33 St & 5 Ave
# E 23 St & 1 Ave
# Grand St & Greene St
# E 72 St & York Ave
# Willoughby Ave & Tompkins Ave
# E 55 St & Lexington Ave
# E 84 St & 1 Ave
# E 39 St & 2 Ave
# E 11 St & Broadway
# St James Pl & Oliver St
# Fulton St & Washington Ave
# 1 Ave & E 44 St
# Nassau Ave & Newell St
# Central Park West & W 76 St
# Nassau Ave & Russell St
# W 26 St & 8 Ave
# W 22 St & 8 Ave
# W 13 St & 7 Ave
# 3 Ave & Schermerhorn St
# 1 Ave & E 18 St
# University Pl & E 14 St
# E 53 St & Lexington Ave
# Broadway & W 51 St
# Huron St & Franklin St
# Christopher St & Greenwich St
# E 58 St & 1 Ave
# Lafayette Ave & Fort Greene Pl
# E 32 St & Park Ave
# Lawrence St & Willoughby St
# E 47 St & Park Ave
# Willoughby St & Fleet St
# W 84 St & Columbus Ave
# Washington St & Gansevoort St
# Cleveland Pl & Spring St
# University Pl & E 8 St
# Bond St & Schermerhorn St
# E 6 St & Avenue B
# Lexington Ave & E 63 St
# 5 Ave & E 29 St
# E 25 St & 1 Ave
# LaGuardia Pl & W 3 St
# W 41 St & 8 Ave
# Canal St & Rutgers St
# W 84 St & Broadway
# Centre St & Worth St
# Bond St & Fulton St
# W 39 St & 9 Ave
# W 13 St & 6 Ave
# Little West St & 1 Pl
# Broadway & W 39 St
# W 47 St & 10 Ave
# MacDougal St & Washington Sq
# Monroe St & Classon Ave
# E 71 St & 2 Ave
# W 38 St & 8 Ave
# W 42 St & 8 Ave
# Lexington Ave & E 29 St
# E 40 St & 5 Ave
# W 18 St & 6 Ave
# Watts St & Greenwich St
# Mott St & Prince St
# 45 Rd & 11 St
# Pershing Square North
# E 84 St & Park Ave
# W Broadway & Spring St
# E 52 St & 2 Ave
# Meserole Ave & Manhattan Ave
# W 52 St & 5 Ave
# E 31 St & 3 Ave
# W 45 St & 6 Ave
# DeKalb Ave & S Portland Ave
# Barclay St & Church St
# Graham Ave & Grand St
# Verona Pl & Fulton St
# Union Ave & Jackson St
# W 31 St & 7 Ave
# Greenwich St & N Moore St
# N 6 St & Bedford Ave
# Cadman Plaza E & Tillary St
# W 14 St & The High Line
# Great Jones St
# 1 Ave & E 15 St
# W 42 St & Dyer Ave
# Grand Army Plaza & Central Park S
# E 48 St & 3 Ave
# E 59 St & Madison Ave
# E 51 St & 1 Ave
# Fulton St & Broadway
# Henry St & Poplar St
# Mercer St & Spring St
# Broadway & W 58 St
# 6 Ave & W 33 St
# Broadway & Whipple St
# W 67 St & Broadway
# W 13 St & 5 Ave
# South St & Whitehall St
# Henry St & Atlantic Ave
# 1 Ave & E 30 St
# Allen St & Rivington St
# E 43 St & 2 Ave
# Myrtle Ave & Marcy Ave
# W 56 St & 10 Ave
# Union Ave & N 12 St
# E 55 St & 2 Ave
# Columbia Heights & Cranberry St
# E 53 St & Madison Ave
# Grand St & Havemeyer St
# 6 Ave & Canal St
# Broadway & W 49 St
# Maiden Ln & Pearl St
# Montrose Ave & Bushwick Ave
# E 33 St & 2 Ave
# 11 Ave & W 41 St
# W 64 St & West End Ave
# Franklin St & W Broadway
# Jay St & Tech Pl
# W 49 St & 8 Ave
# Lexington Ave & E 24 St
# E 13 St & Avenue A
# E 77 St & Park Ave
# Pershing Square South
# 1 Ave & E 68 St
# 21 St & 43 Ave
# 12 Ave & W 40 St
# W 82 St & Central Park West
# W 63 St & Broadway
# W 24 St & 7 Ave
# Albany Ave & Fulton St
# Warren St & Church St
# 21 St & 41 Ave
# Clermont Ave & Park Ave
# Bayard St & Baxter St
# Kosciuszko St & Tompkins Ave
# Spruce St & Nassau St
# 46 Ave & 5 St
# E 10 St & Avenue A
# N 15 St & Wythe Ave
# E 15 St & 3 Ave
# E 16 St & Irving Pl
# E 7 St & Avenue A
# Peck Slip & Front St
# State St & Smith St
# W 70 St & Amsterdam Ave
# 8 Ave & W 52 St
# MacDougal St & Prince St
# Leonard St & Bayard St
# 9 Ave & W 18 St
# 2 Ave & E 31 St
# Washington Ave & Park Ave
# E 56 St & Madison Ave
# Driggs Ave & Lorimer St
# South End Ave & Liberty St
# McGuinness Blvd & Eagle St
# Howard St & Centre St
# Clinton St & Joralemon St
# Clinton St & Grand St
# Montague St & Clinton St
# N 8 St & Driggs Ave
# Greene Ave & Nostrand Ave
# 44 Dr & Jackson Ave
# 6 Ave & Broome St
# Laight St & Hudson St
# Broadway & W 53 St
# Queens Plaza North & Crescent St
# Lewis Ave & Kosciuszko St
# E 20 St & FDR Drive
# 9 Ave & W 22 St
# E 60 St & York Ave
# Broadway & W 41 St
# W 56 St & 6 Ave
# Pearl St & Anchorage Pl
# Pike St & Monroe St
# W 43 St & 6 Ave
# Lewis Ave & Madison St
# Kent Ave & N 7 St
# W 25 St & 6 Ave
# Riverside Dr & W 78 St
# E 19 St & 3 Ave
# Schermerhorn St & Court St
# Wythe Ave & Metropolitan Ave
# W 44 St & 5 Ave
# Pitt St & Stanton St
# Water - Whitehall Plaza
# Bank St & Washington St
# E 11 St & 1 Ave
# W 22 St & 10 Ave
# 8 Ave & W 33 St
# W 51 St & 6 Ave
# W 37 St & 10 Ave
# Center Blvd & Borden Ave
# E 4 St & 2 Ave
# Fulton St & Rockwell Pl
# N 12 St & Bedford Ave
# W 78 St & Broadway
# Broadway & W 37 St
# 31 St & Thomson Ave
# Division St & Bowery
# Broadway & Battery Pl
# Penn Station Valet
# Putnam Ave & Nostrand Ave
# W 45 St & 8 Ave
# Fulton St & Clermont Ave
# S Portland Ave & Hanson Pl
# Rivington St & Chrystie St
# S 5 Pl & S 4 St
# Broad St & Bridge St
# Macon St & Nostrand Ave
# W 20 St & 8 Ave
# Perry St & Bleecker St
# E 25 St & 2 Ave
# Carlton Ave & Flushing Ave
# Hanson Pl & St Felix St
# Clinton St & Tillary St
# DeKalb Ave & Vanderbilt Ave
# Elizabeth St & Hester St
# Brooklyn Bridge Park - Pier 2
# Suffolk St & Stanton St
# Central Park West & W 85 St
# East End Ave & E 86 St
# Broadway & W 55 St
